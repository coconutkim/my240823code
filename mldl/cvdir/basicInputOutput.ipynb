# %%
import cv2 as cv

# %%
quaka=cv.imread('C:/ex/img/ai-generated-8244720_1280.webp',
                flags=cv.IMREAD_GRAYSCALE) #흑백 이미지로 나오게 한다
quaka

# %%
# 컬러 이미지를 흑백으로

# 이미지 흑백으로 불러오기
quaka = cv.imread('C:/ex/img/ai-generated-8244720_1280.webp', flags=cv.IMREAD_GRAYSCALE)

# 이미지를 윈도우로 표시
cv.imshow('Quaka Gray Image', quaka)

# 흑백 이미지를 저장한다
cv.imwrite('C:/ex/img/gray_quaka.jpg',quaka)

# 키 입력을 기다림 (0이면 무한정 기다림)
cv.waitKey(0)

# 모든 윈도우 닫기
cv.destroyAllWindows()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import cv2 as cv

# 흑백 이미지 읽기
quakaGray = cv.imread('C:/ex/img/gray_quaka.jpg', cv.IMREAD_GRAYSCALE)

# GRAY -> BGR 변환
quakaBackToColor = cv.cvtColor(quakaGray, cv.COLOR_GRAY2BGR)

# 변환된 이미지 표시
cv.imshow('quaka', quakaBackToColor)

# 이미지 저장
cv.imwrite('C:/ex/img/quaka_back.jpg', quakaBackToColor)

# 5초 후 창 닫기
cv.waitKey(5000)
cv.destroyAllWindows()

# 결과: 새로 생성된 이미지가 컬러가 아니다

# COLOR_GRAY2BGR
# 단순히 이미지를 색상 채널로 복사하기만 하고
# 실제로 컬러 정보를 추가하지 않기 때문이다

# 이미지를 bgr 형식으로 바꾸지만
# 모든 채널의 값이 동이하게 흑백으로 채워진다

# 여전히 흑백이다

# %%
import numpy as np

# %%
# 흑백 이미지 읽기
quakaGray = cv.imread('C:/ex/img/gray_quaka.jpg',
                      cv.IMREAD_GRAYSCALE)

# GRAY -> BGR 변환
quakaBackToColor = cv.cvtColor(quakaGray, cv.COLOR_GRAY2BGR)

# 단순히 한 가지 색상으로 변환하는 경우 (예: 빨간색)
quakaBackToColor[:, :, 1] = 0  # Green 채널 제거
quakaBackToColor[:, :, 2] = 0  # Blue 채널 제거

# 변환된 이미지 표시
cv.imshow('quaka', quakaBackToColor)

# 이미지 저장
cv.imwrite('C:/ex/img/quaka_back.jpg', quakaBackToColor)

# 5초 후 창 닫기
cv.waitKey(5000)
cv.destroyAllWindows()

# 결과: 그냥 파랗기만 하다

# 원래 색상으로 되돌리기 위해서는
# 딥러닝 모델이 필요하다

# %% [markdown]
# # 카메라와 동영상 파일 다루기

# %%
import cv2

# %%
cap=cv2.VideoCapture(0)

# %%
cap.isOpened()

# %%
if cap.isOpened(): # 카메라가 정상적으로 열렸는지 확인한다
    while True:
        ret,img=cap.read() # 현재 카메라에서 프레임을 읽어온다
        if ret:
            cv2.imshow('camera',img)
            if cv2.waitKey(1) != -1:
                break
        else:
            print('no frame')
            break
else:
    print("can't open camera.")
cap.release()
cv2.destroyAllWindows()

# %%
import cv2

cap = cv2.VideoCapture(0)               # 0번 카메라 장치 연결 ---①
if cap.isOpened():                      # 캡쳐 객체 연결 확인
    while True:
        ret, img = cap.read()           # 다음 프레임 읽기
        if ret:
            cv2.imshow('camera', img)   # 다음 프레임 이미지 표시
            if cv2.waitKey(1) != -1:    # 1ms 동안 키 입력 대기 ---②
                break                   # 아무 키라도 입력이 있으면 중지
        else:
            print('no frame')
            break
else:
    print("can't open camera.")
cap.release()                           # 자원 반납
cv2.destroyAllWindows()

# %% [markdown]
# # 지연 시간 구하기

# %%
try:
    fps=cap.get(cv2.CAP_PROP_FPS) # FRAME PER SECOND
    delay=int(1000/fps)
except E(e):
    print('0으로 나눔')

# %%
if cap.isOpened(): # 카메라가 정상적으로 열렸는지 확인한다
    while True:
        ret,img=cap.read() # 현재 카메라에서 프레임을 읽어온다
        if ret:
            cv2.imshow('camera',img)
            if cv2.waitKey(1) != -1:
                break
        else:
            print('no frame')
            break
else:
    print("can't open camera.")

# %%
import cv2

video_file = "../img/big_buck.avi" # 동영상 파일 경로

cap = cv2.VideoCapture(video_file) # 동영상 캡쳐 객체 생성
if cap.isOpened():                 # 캡쳐 객체 초기화 확인
    fps = cap.get(cv2.CAP_PROP_FPS) # 프레임 수 구하기
    delay = int(1000/fps)
    print("FPS: %f, Delay: %dms" %(fps, delay))

    while True:
        ret, img = cap.read()      # 다음 프레임 읽기
        if ret:                     # 프레임 읽기 정상
            cv2.imshow(video_file, img) # 화면에 표시
            cv2.waitKey(delay)            # fps에 맞게 시간 지연
        else:
            break                   # 다음 프레임 읽을 수 없슴, 재생 완료
else:
    print("can't open video.")      # 캡쳐 객체 초기화 실패
cap.release()                       # 캡쳐 자원 반납
cv2.destroyAllWindows()

# %%
import cv2

cap = cv2.VideoCapture(0)                       # 0번 카메라 연결
if cap.isOpened() :
    while True:
        ret, frame = cap.read()                 # 카메라 프레임 읽기
        if ret:
            cv2.imshow('camera',frame)          # 프레임 화면에 표시
            if cv2.waitKey(1) != -1:            # 아무 키나 누르면
                cv2.imwrite('photo.jpg', frame) # 프레임을 'photo.jpg'에 저장
                break
        else:
            print('no frame!')
            break
else:
    print('no camera!')
cap.release()
cv2.destroyAllWindows()

# %%
import cv2

cap = cv2.VideoCapture(0)                   # 카메라 0번 장치 연결
width = cap.get(cv2.CAP_PROP_FRAME_WIDTH)   # 프레임 폭 값 구하기
height = cap.get(cv2.CAP_PROP_FRAME_HEIGHT) # 프레임 높이 값 구하기
print("Original width: %d, height:%d" % (width, height) ) 

cap.set(cv2.CAP_PROP_FRAME_WIDTH, 320)      # 프레임 폭을 320으로 설정 
cap.set(cv2.CAP_PROP_FRAME_HEIGHT, 240)     # 프레임 높이를 240으로 설정
width = cap.get(cv2.CAP_PROP_FRAME_WIDTH)   # 재지정한 프레임 폭 값 구하기
height = cap.get(cv2.CAP_PROP_FRAME_HEIGHT) # 재지정한 프레임 폭 값 구하기

print("Resized width: %d, height:%d" % (width, height) )
if cap.isOpened():
    while True:
        ret, img = cap.read()
        if ret:
            cv2.imshow('camera', img)
            if cv2.waitKey(1) != -1:
                break
        else:
            print('no frame!')
            break
else:
    print("can't open camera!")
cap.release()
cv2.destroyAllWindows()

# %%
import cv2

img = cv2.imread('../img/blank_500.jpg')

cv2.line(img, (50, 50), (150, 50), (255,0,0))   # 파란색 1픽셀 선
cv2.line(img, (200, 50), (300, 50), (0,255,0))  # 초록색 1픽셀 선
cv2.line(img, (350, 50), (450, 50), (0,0,255))  # 빨간색 1픽셀 선

# 하늘색(파랑+초록) 10픽셀 선      
cv2.line(img, (100, 100), (400, 100), (255,255,0), 10)          
# 분홍(파랑+빨강) 10픽셀 선      
cv2.line(img, (100, 150), (400, 150), (255,0,255), 10)          
# 노랑(초록+빨강) 10픽셀 선      
cv2.line(img, (100, 200), (400, 200), (0,255,255), 10)          
# 회색(파랑+초록+빨강) 10픽셀 선  
cv2.line(img, (100, 250), (400, 250), (200,200,200), 10)        
# 검정 10픽셀 선    
cv2.line(img, (100, 300), (400, 300), (0,0,0), 10)                    

# 4연결 선
cv2.line(img, (100, 350), (400, 400), (0,0,255), 20, cv2.LINE_4)   
# 8연결 선
cv2.line(img, (100, 400), (400, 450), (0,0,255), 20, cv2.LINE_8)    
# 안티에일리어싱 선 
cv2.line(img, (100, 450), (400, 500), (0,0,255), 20, cv2.LINE_AA)   
# 이미지 전체에 대각선 
cv2.line(img, (0,0), (500,500), (0,0,255))                      

cv2.imshow('lines', img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# polylines(img,꼭짓점좌표 배열),isClosed, 색상(BGR), 선두께)

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rc
import matplotlib.pyplot as plt
# OpenCV에서 사용할 이미지를 생성
image = np.zeros((300, 600, 3), dtype=np.uint8)
image[:] = (255, 255, 255)  # 흰색 배경
# matplotlib으로 한글 텍스트 렌더링
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False  # 음수 기호 표시 문제 해결
plt.figure(figsize=(6, 3))
plt.text(0.5, 0.5, '안녕하세요, OpenCV!', fontsize=20, ha='center', va='center')
plt.axis('off')
# 렌더링한 이미지를 가져오기
plt.draw()
text_image = np.frombuffer(plt.gcf().canvas.tostring_rgb(), dtype=np.uint8)
text_image = text_image.reshape(
    plt.gcf().canvas.get_width_height()[::-1] + (3,))
# OpenCV 이미지에 텍스트 이미지 추가
text_image = cv2.cvtColor(text_image, cv2.COLOR_RGB2BGR)
image = cv2.addWeighted(image, 0.5, text_image, 0.5, 0)
# 결과 이미지 표시
cv2.imshow("Image", image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# C:\Users\acy\AppData\Local\Temp\ipykernel_18788\1556261584.py:17: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed in 3.10. Use buffer_rgba instead.
#   text_image = np.frombuffer(plt.gcf().canvas.tostring_rgb(), dtype=np.uint8)

# %%
import cv2
import numpy as np
from PIL import ImageFont, ImageDraw, Image

# 빈 이미지 생성 (배경은 흰색)
image = np.zeros((500, 500, 3), dtype="uint8")
image.fill(255)  # 흰색 배경
# OpenCV 이미지를 Pillow 이미지로 변환
pil_image = Image.fromarray(image)
# 폰트 설정 (폰트 파일 경로와 크기 설정)
fontpath = "./MALGUN.TTF"  # TTF 폰트 파일 경로를 지정
font = ImageFont.truetype(fontpath, 40)  # 폰트 크기를 40으로 설정
# ImageDraw 객체 생성
draw = ImageDraw.Draw(pil_image)
# 한글 텍스트 그리기
text = "한글 텍스트"
draw.text((50, 200), text, font=font, fill=(0, 0, 0, 0))  # (x, y) 좌표에 텍스트 그리기
# Pillow 이미지를 다시 OpenCV 이미지로 변환
image = np.array(pil_image)
# 이미지 출력
cv2.imshow("Image with Korean Text", image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[4], line 12
#      10 # 폰트 설정 (폰트 파일 경로와 크기 설정)
#      11 fontpath = "./MALGUN.TTF"  # TTF 폰트 파일 경로를 지정
# ---> 12 font = ImageFont.truetype(fontpath, 40)  # 폰트 크기를 40으로 설정
#      13 # ImageDraw 객체 생성
#      14 draw = ImageDraw.Draw(pil_image)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\PIL\ImageFont.py:834, in truetype(font, size, index, encoding, layout_engine)
#     831     return FreeTypeFont(font, size, index, encoding, layout_engine)
#     833 try:
# --> 834     return freetype(font)
#     835 except OSError:
#     836     if not is_path(font):
#
# File ~\AppData\Roaming\Python\Python39\site-packages\PIL\ImageFont.py:831, in truetype.<locals>.freetype(font)
#     830 def freetype(font: StrOrBytesPath | BinaryIO | None) -> FreeTypeFont:
# --> 831     return FreeTypeFont(font, size, index, encoding, layout_engine)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\PIL\ImageFont.py:257, in FreeTypeFont.__init__(self, font, size, index, encoding, layout_engine)
#     255                 load_from_bytes(f)
#     256             return
# --> 257     self.font = core.getfont(
#     258         font, size, index, encoding, layout_engine=layout_engine
#     259     )
#     260 else:
#     261     load_from_bytes(font)
#
# OSError: cannot open resource
