# %%
import tensorflow as tf

# %%
# study_time = [2,4,6,8]
# score = [81,93.91.97]

# %%
import numpy as np

# %%
np.array([[2,81],
          [4,93],
          [6,91],
          [8,97]])
# Out:
# array([[ 2, 81],
#        [ 4, 93],
#        [ 6, 91],
#        [ 8, 97]])

# %%
X_y = np.array([[2,81],
          [4,93],
          [6,91],
          [8,97]])

# %%
X_y[:,0]
# Out:
# array([2, 4, 6, 8])

# %%
study_mean = X_y[:,0].mean()

# %%
score_mean = X_y[:,1].mean()

# %%
# x편차

# %%
X_y[:,0] - study_mean
# Out:
# array([-3., -1.,  1.,  3.])

# %%
# y편차

# %%
X_y[:,1] - score_mean
# Out:
# array([-9.5,  2.5,  0.5,  6.5])

# %%
(X_y[:,0] - study_mean)*(X_y[:,1] - score_mean)
# Out:
# array([28.5, -2.5,  0.5, 19.5])

# %%
sum((X_y[:,0] - study_mean)*(X_y[:,1] - score_mean))
# Out:
# 46.0

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a = sum((X_y[:,0] - study_mean)*(X_y[:,1] - score_mean)) /\
(sum((X_y[:,0] - study_mean)**2))

# %%
a
# Out:
# 2.3

# %%
intercept = score_mean-(study_mean*a)

# %%
intercept
# Out:
# 79.0

# %%
# 회귀모델

# %%
# y = 2.3x+79

# %%
# 평균 제곱 오차

# %%
fake_a = 3
fake_b = 76

# %%
def predict(x):
    return fake_a*x+fake_b

# %%
predict_result = []

# %%
x = np.array([2,4,6,8])
y = np.array([81,93,91,97])

# %%
for i in range(len(x)):
    predict_result.append(predict(x[i]))
    print('study time =%.2f,real score =%.2f,predict score =%.2f ' %(x[i],y[i],predict(x[i])))
# Out:
# study time =2.00,real score =81.00,predict score =82.00
# study time =4.00,real score =93.00,predict score =88.00
# study time =6.00,real score =91.00,predict score =94.00
# study time =8.00,real score =97.00,predict score =100.00

# %%
n=len(x)
def mse(y,y_pred):
    return (1/n)*sum((y-y_pred)**2)

# %%
print('평균 제곱 오차:' +str(mse(y,predict_result)))
# Out:
# 평균 제곱 오차:11.0

# %%
# 가상환경 내부에 있기 때문에 안 깔릴 수가 있다
# 아나콘다 프롬트에서 가상환경 실행하고 pip install sympy

# C:\ProgramData\anaconda3\envs\mldltest1\Lib\site-packages
# 심파이 위치
import sympy as sp

# %%
a,x,b = sp.symbols('a x b')
# 대문자 심볼이 아니다
# 심볼스

# %%
print(a,x,b)
# Out:
# a x b

# %%
y = (a*x+b)**2

# %%
y
# Out:
# (a*x + b)**2

# %%
y.expand()
# Out:
# a**2*x**2 + 2*a*b*x + b**2

# %%
sp.diff(y,a)
# Out:
# 2*x*(a*x + b)

# %%
sp.diff(y,b)
# Out:
# 2*a*x + 2*b

# %%
x
# Out:
# x

# %%
x = np.array([2,4,6,8])
y = np.array([81,93,91,97])

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(x,y,'or')
plt.plot()
# Out:
# []

# %%
plt.scatter(x,y)
plt.plot()
# Out:
# []

# %%
# 매개변수 parameter,weight 초기화

# %%
a, b = 0,0

# %%
learning_rate = 0.03 #학습률

# %%
epochs = 2001

# %%
n = len(x)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
for i in range(epochs):
    y_pred = a*x+b
    error = y-y_pred
    
    a_diff = (2/n)*sum(-x*(error))
    b_diff = (2/n)*sum(-(error))
    
    a = a-learning_rate*a_diff
    b = b-learning_rate*b_diff
    
    if i%100==0:
        print('epoch=%.f, 기울기=%.04f, 절편 = %.04f'%(i,a,b))
# Out:
# epoch=0, 기울기=27.8400, 절편 = 5.4300
# epoch=100, 기울기=7.0739, 절편 = 50.5117
# epoch=200, 기울기=4.0960, 절편 = 68.2822
# epoch=300, 기울기=2.9757, 절편 = 74.9678
# epoch=400, 기울기=2.5542, 절편 = 77.4830
# epoch=500, 기울기=2.3956, 절편 = 78.4293
# epoch=600, 기울기=2.3360, 절편 = 78.7853
# epoch=700, 기울기=2.3135, 절편 = 78.9192
# epoch=800, 기울기=2.3051, 절편 = 78.9696
# epoch=900, 기울기=2.3019, 절편 = 78.9886
# epoch=1000, 기울기=2.3007, 절편 = 78.9957
# epoch=1100, 기울기=2.3003, 절편 = 78.9984
# epoch=1200, 기울기=2.3001, 절편 = 78.9994
# epoch=1300, 기울기=2.3000, 절편 = 78.9998
# epoch=1400, 기울기=2.3000, 절편 = 78.9999
# epoch=1500, 기울기=2.3000, 절편 = 79.0000
# epoch=1600, 기울기=2.3000, 절편 = 79.0000
# epoch=1700, 기울기=2.3000, 절편 = 79.0000
# epoch=1800, 기울기=2.3000, 절편 = 79.0000
# epoch=1900, 기울기=2.3000, 절편 = 79.0000
# epoch=2000, 기울기=2.3000, 절편 = 79.0000

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
plt.scatter(x,y)
plt.plot(x,y_pred,'r')
plt.show()

# %% [markdown]
# # 다중 선형 회귀

# %%
import matplotlib.pyplot as plt

# %%
from matplotlib import rc

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %%
x1 = np.array([2,4,6,8])
x2 = np.array([0,4,2,3])
y = np.array([81,93,91,97])
fig = plt.figure()
ax = fig.add_subplot(111,projection='3d')
ax.scatter3D(x1,x2,y)
ax.set_xlabel('공부한시간')
ax.set_ylabel('과외 횟수')
ax.set_zlabel('성적')
plt.rcParams['font.family'] = 'Malgun Gothic' #띄어쓰기 주의
plt.rcParams['axes.unicode_minus'] = False
plt.show()
# Out:
# c:\ProgramData\anaconda3\envs\mldltest1\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 44277 (\N{HANGUL SYLLABLE GONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\ProgramData\anaconda3\envs\mldltest1\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 48512 (\N{HANGUL SYLLABLE BU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\ProgramData\anaconda3\envs\mldltest1\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 54620 (\N{HANGUL SYLLABLE HAN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\ProgramData\anaconda3\envs\mldltest1\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 49884 (\N{HANGUL SYLLABLE SI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\ProgramData\anaconda3\envs\mldltest1\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 44036 (\N{HANGUL SYLLABLE GAN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\ProgramData\anaconda3\envs\mldltest1\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 44284 (\N{HANGUL SYLLABLE GWA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\ProgramData\anaconda3\envs\mldltest1\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 50808 (\N{HANGUL SYLLABLE OE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\ProgramData\anaconda3\envs\mldltest1\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 54943 (\N{HANGUL SYLLABLE HOES}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\ProgramData\anaconda3\envs\mldltest1\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\ProgramData\anaconda3\envs\mldltest1\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 49457 (\N{HANGUL SYLLABLE SEONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\ProgramData\anaconda3\envs\mldltest1\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 51201 (\N{HANGUL SYLLABLE JEOG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
a1,a2,b=0,0,0
y_pred = a1*x1+a2*x2+b

# %%
error = y-y_pred

# %%
n = len(x1)
a1_diff=(2/n)*sum(-x1*(error))
a2_diff=(2/n)*sum(-x2*(error))
b_diff=(2/n)*sum(-(error))

# %%
learning_rate=0.03 #hyper parameter #학습률 #에타

# %%
# a1 = a1-learning_rate*a1_diff
# a2 = a2-learning_rate*a2_diff
# b = b-learning_rate*b_diff

# %%
# stop early: 조기 멈춤. 모델을 돌리다가 멈춰라

# %%
epochs = 2001

# %%
x1 = np.array([2,4,6,8])
x2 = np.array([0,4,2,3])
y = np.array([81,93,91,97])

a1,a2,b=0,0,0

epochs = 2001

learning_rate=0.03

n = len(x)

for i in range(epochs):
    y_pred=a1*x1+a2*x2+b
    error=y-y_pred #오차
    a1_diff=(2/n)*sum(-x1*(error))
    a2_diff=(2/n)*sum(-x2*(error))
    b_diff=(2/n)*sum(-(error))
    
    a1 = a1-learning_rate*a1_diff
    a2 = a2-learning_rate*a2_diff
    b = b-learning_rate*b_diff
    
    if i%100==0:
        print('epochs=%.f, 기울기1=%.04f, 기울기2=%.04f, 절편=%.04f' %(i,a1,a2,b))
# Out:
# epochs=0, 기울기1=27.8400, 기울기2=12.6750, 절편=5.4300
# epochs=100, 기울기1=1825213494.7590, 기울기2=828060192.2304, 절편=307475310.2288
# epochs=200, 기울기1=218096624120368320.0000, 기울기2=98945757721862256.0000, 절편=36740533022271224.0000
# epochs=300, 기울기1=26060588384748178287624192.0000, 기울기2=11823129655520672163561472.0000, 절편=4390163818405644046696448.0000
# epochs=400, 기울기1=3114006324941753918302910033166336.0000, 기울기2=1412757838938314719145075968835584.0000, 절편=524585158869494312454076558737408.0000
# epochs=500, 기울기1=372095796480650616171454575141926622724096.0000, 기울기2=168811877196128470263937101527958926917632.0000, 절편=62683216455934456246555914802930844172288.0000
# epochs=600, 기울기1=44462106788161230307565329811045240501455206481920.0000, 기울기2=20171503634265136376509643496560336199593836412928.0000, 절편=7490081560311616598206793780057083655592765030400.0000
# epochs=700, 기울기1=5312822554674177050052919804968916326066718700504329748480.0000, 기울기2=2410313572868101005115905117263239109449795824466285035520.0000, 절편=894997496172816197741653247695118975921606654269715382272.0000
# epochs=800, 기울기1=634834593689795935850411736790473553804230077596007468522104946688.0000, 기울기2=288010830768384455121691611277726562358355116523823147391349948416.0000, 절편=106944164987475165222463443145189270003723443345661967182810054656.0000
# epochs=900, 기울기1=75857034033767762388425173333319412227844183998665522178623935784289304576.0000, 기울기2=34414708349001304743860416252233318870451640855395441559897907549616209920.0000, 절편=12778867509434810255919365861275257738967769823931854000050603771679473664.0000
# epochs=1000, 기울기1=9064234478708884615121369174657736096179533389356266315327401672079833195345870848.0000, 기울기2=4112248652549044883307786611581967322648148388247765509356431474372657226180460544.0000, 절편=1526959931313815691885828864684813937354478635061444959135649368401121959399653376.0000
# epochs=1100, 기울기1=1083094636265916151872732701480312735457751860676256270358759225786069015204361433977454592.0000, 기울기2=491376791832732055777576265636601800953040961163652262149858527231521428834775442982436864.0000, 절편=182458001862562025887774956590498040471687856640828341924658236984841339797564877403324416.0000
# epochs=1200, 기울기1=129420084383683424910285690009927257110722675674516645971264355035962414123678438963812195989716992.0000, 기울기2=58715114758967853163916463388110930883152187856613713486608896638685317321511549842580667889614848.0000, 절편=21802093009103893964134976508862575160313629260918433991228210734236622201484137361160382938349568.0000
# epochs=1300, 기울기1=15464538075477515151276460070526892616486626834899948911786403889407685652199752544703594771557029857198080.0000, 기울기2=7015929035436222160319986795178489190834891020283232857730033710458735285699265624056753452316357247893504.0000, 절편=2605154362786804543206038242154635614510745077339129823464437921359975358017814930186654646313137465196544.0000
# epochs=1400, 기울기1=1847873450452215819445187735888314445611503899142482241497017346513818975604050255502118421793968940905375656312832.0000, 기울기2=838340526665818063906039705790183348964953096172913639456610383605252453227080936218044231964195869670397947412480.0000, 절편=311292555770363611435513030260032207343725240029270698481892431748118129648904494801309853115296003293414032408576.0000
# epochs=1500, 기울기1=220804286052414285126147970152066404581401822270017800536077723105382610929544965437923502454020617801942583782519726931968.0000, 기울기2=100174165830430948165563929744964681277278263485820485034709760027324195331520825496391206915076912328841584370538751459328.0000, 절편=37196665449944929294666510215632763151075979378745070772403772907173547596528693583947464380176847626116025426342026674176.0000
# epochs=1600, 기울기1=26384129674672808493297392222619795868541306029304320507155920803025848907394196836692700827750861869576849054703034984948933066752.0000, 기울기2=11969913395136158368221867737953823040774694583221047738522306398865961228785398419627971454184195979281105406832436068572746219520.0000, 절편=4444667548091913563121393274284580500107712548571946028252003236483870418966572337610631971355257594620838820115754235140851630080.0000
# epochs=1700, 기울기1=3152666604146922630018911354630175326564895904727125553806081055204902882725852997575210520839911440546054141918114001160749320982369402880.0000, 기울기2=1430297177913056994323512642935229906496851373864514069141310341488707853630095518268233655741189971230929673840604382832485925179982086144.0000, 절편=531097865200995138583080652791658396038372853402634251776171360441904143427044544803615905990574534271542656844329955111451539069298802688.0000
# epochs=1800, 기울기1=376715352731321581159660887483244032232275565856085906957003135234074118740101276014458306888706553553685048013957471123076281792505111259876687872.0000, 기울기2=170907670725280698557582429603044544334637689967427161351055086226389326122604171404516268954307284585552496028379723968355031189189164873262563328.0000, 절편=63461426387704703441877518832541479763132450830699733922107906511090618078857122388736490257386785810967240860061484234344357372617882662003015680.0000
# epochs=1900, 기울기1=45014102283068503294043232657691612754427481724517934983278147786261918730546790449390318591482256013636209695698836769841838171552983501849338466954903552.0000, 기울기2=20421932143752360509473098539802606181489721101625825656980258398245533113681627177414256843148052015544879996580793092594977829839186910392942533715951616.0000, 절편=7583070659939279217301638823186784405009411647692009371253698860839509904548426771067288878939103335480932785032047092910708084447930373081583612910895104.0000
# epochs=2000, 기울기1=5378781060180785860727001285101497113278191916975607923965444456437799444864162195487895301608801835970512402361361221821273263378587000350616904943385109864644608.0000, 기울기2=2440237531259822885722212034709558979054751179086389642818214597423075360232543715057885554808839556324045314578992252693735993904458167083701957235849468661727232.0000, 절편=906108858668403785879815786673017265880168888586472970092925174478060886697223334533039704552375379974504588659761397148469983979950351257614360959411033387040768.0000

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
x1 = np.array([2,4,6,8])
x2 = np.array([0,4,2,3])
y = np.array([81,93,91,97])

a1,a2,b=0,0,0

epochs = 3001

learning_rate=0.01

n = len(x1)

for i in range(epochs):
    y_pred=a1*x1+a2*x2+b
    error=y-y_pred #오차
    a1_diff=(2/n)*sum(-x1*(error))
    a2_diff=(2/n)*sum(-x2*(error))
    b_diff=(2/n)*sum(-(error))
    
    a1 = a1-learning_rate*a1_diff
    a2 = a2-learning_rate*a2_diff
    b = b-learning_rate*b_diff
    
    if i%100==0:
        print('epochs=%.f, 기울기1=%.04f, 기울기2=%.04f, 절편=%.04f' %(i,a1,a2,b))
# Out:
# epochs=0, 기울기1=9.2800, 기울기2=4.2250, 절편=1.8100
# epochs=100, 기울기1=9.5110, 기울기2=5.0270, 절편=22.9205
# epochs=200, 기울기1=7.3238, 기울기2=4.2950, 절편=37.8751
# epochs=300, 기울기1=5.7381, 기울기2=3.7489, 절편=48.7589
# epochs=400, 기울기1=4.5844, 기울기2=3.3507, 절편=56.6800
# epochs=500, 기울기1=3.7447, 기울기2=3.0608, 절편=62.4448
# epochs=600, 기울기1=3.1337, 기울기2=2.8498, 절편=66.6404
# epochs=700, 기울기1=2.6890, 기울기2=2.6962, 절편=69.6938
# epochs=800, 기울기1=2.3653, 기울기2=2.5845, 절편=71.9160
# epochs=900, 기울기1=2.1297, 기울기2=2.5032, 절편=73.5333
# epochs=1000, 기울기1=1.9583, 기울기2=2.4440, 절편=74.7103
# epochs=1100, 기울기1=1.8336, 기울기2=2.4009, 절편=75.5670
# epochs=1200, 기울기1=1.7428, 기울기2=2.3695, 절편=76.1904
# epochs=1300, 기울기1=1.6767, 기울기2=2.3467, 절편=76.6441
# epochs=1400, 기울기1=1.6286, 기울기2=2.3301, 절편=76.9743
# epochs=1500, 기울기1=1.5936, 기울기2=2.3180, 절편=77.2146
# epochs=1600, 기울기1=1.5681, 기울기2=2.3092, 절편=77.3895
# epochs=1700, 기울기1=1.5496, 기울기2=2.3028, 절편=77.5168
# epochs=1800, 기울기1=1.5361, 기울기2=2.2982, 절편=77.6095
# epochs=1900, 기울기1=1.5263, 기울기2=2.2948, 절편=77.6769
# epochs=2000, 기울기1=1.5191, 기울기2=2.2923, 절편=77.7260
# epochs=2100, 기울기1=1.5139, 기울기2=2.2905, 절편=77.7617
# epochs=2200, 기울기1=1.5101, 기울기2=2.2892, 절편=77.7877
# epochs=2300, 기울기1=1.5074, 기울기2=2.2883, 절편=77.8066
# epochs=2400, 기울기1=1.5054, 기울기2=2.2876, 절편=77.8203
# epochs=2500, 기울기1=1.5039, 기울기2=2.2871, 절편=77.8304
# epochs=2600, 기울기1=1.5028, 기울기2=2.2867, 절편=77.8376
# epochs=2700, 기울기1=1.5021, 기울기2=2.2864, 절편=77.8430
# epochs=2800, 기울기1=1.5015, 기울기2=2.2862, 절편=77.8468
# epochs=2900, 기울기1=1.5011, 기울기2=2.2861, 절편=77.8496
# epochs=3000, 기울기1=1.5008, 기울기2=2.2860, 절편=77.8517

# %%
x1 = np.array([2,4,6,8])
x2 = np.array([0,4,2,3])
y = np.array([81,93,91,97])

a1,a2,b=0,0,0

epochs = 5001

learning_rate=0.01

n = len(x1)

for i in range(epochs):
    y_pred=a1*x1+a2*x2+b
    error=y-y_pred #오차
    a1_diff=(2/n)*sum(-x1*(error))
    a2_diff=(2/n)*sum(-x2*(error))
    b_diff=(2/n)*sum(-(error))
    
    a1 = a1-learning_rate*a1_diff
    a2 = a2-learning_rate*a2_diff
    b = b-learning_rate*b_diff
    
    if i%100==0:
        print('epochs=%.f, 기울기1=%.04f, 기울기2=%.04f, 절편=%.04f' %(i,a1,a2,b))
# Out:
# epochs=0, 기울기1=9.2800, 기울기2=4.2250, 절편=1.8100
# epochs=100, 기울기1=9.5110, 기울기2=5.0270, 절편=22.9205
# epochs=200, 기울기1=7.3238, 기울기2=4.2950, 절편=37.8751
# epochs=300, 기울기1=5.7381, 기울기2=3.7489, 절편=48.7589
# epochs=400, 기울기1=4.5844, 기울기2=3.3507, 절편=56.6800
# epochs=500, 기울기1=3.7447, 기울기2=3.0608, 절편=62.4448
# epochs=600, 기울기1=3.1337, 기울기2=2.8498, 절편=66.6404
# epochs=700, 기울기1=2.6890, 기울기2=2.6962, 절편=69.6938
# epochs=800, 기울기1=2.3653, 기울기2=2.5845, 절편=71.9160
# epochs=900, 기울기1=2.1297, 기울기2=2.5032, 절편=73.5333
# epochs=1000, 기울기1=1.9583, 기울기2=2.4440, 절편=74.7103
# epochs=1100, 기울기1=1.8336, 기울기2=2.4009, 절편=75.5670
# epochs=1200, 기울기1=1.7428, 기울기2=2.3695, 절편=76.1904
# epochs=1300, 기울기1=1.6767, 기울기2=2.3467, 절편=76.6441
# epochs=1400, 기울기1=1.6286, 기울기2=2.3301, 절편=76.9743
# epochs=1500, 기울기1=1.5936, 기울기2=2.3180, 절편=77.2146
# epochs=1600, 기울기1=1.5681, 기울기2=2.3092, 절편=77.3895
# epochs=1700, 기울기1=1.5496, 기울기2=2.3028, 절편=77.5168
# epochs=1800, 기울기1=1.5361, 기울기2=2.2982, 절편=77.6095
# epochs=1900, 기울기1=1.5263, 기울기2=2.2948, 절편=77.6769
# epochs=2000, 기울기1=1.5191, 기울기2=2.2923, 절편=77.7260
# epochs=2100, 기울기1=1.5139, 기울기2=2.2905, 절편=77.7617
# epochs=2200, 기울기1=1.5101, 기울기2=2.2892, 절편=77.7877
# epochs=2300, 기울기1=1.5074, 기울기2=2.2883, 절편=77.8066
# epochs=2400, 기울기1=1.5054, 기울기2=2.2876, 절편=77.8203
# epochs=2500, 기울기1=1.5039, 기울기2=2.2871, 절편=77.8304
# epochs=2600, 기울기1=1.5028, 기울기2=2.2867, 절편=77.8376
# epochs=2700, 기울기1=1.5021, 기울기2=2.2864, 절편=77.8430
# epochs=2800, 기울기1=1.5015, 기울기2=2.2862, 절편=77.8468
# epochs=2900, 기울기1=1.5011, 기울기2=2.2861, 절편=77.8496
# epochs=3000, 기울기1=1.5008, 기울기2=2.2860, 절편=77.8517
# epochs=3100, 기울기1=1.5006, 기울기2=2.2859, 절편=77.8532
# epochs=3200, 기울기1=1.5004, 기울기2=2.2859, 절편=77.8542
# epochs=3300, 기울기1=1.5003, 기울기2=2.2858, 절편=77.8550
# epochs=3400, 기울기1=1.5002, 기울기2=2.2858, 절편=77.8556
# epochs=3500, 기울기1=1.5002, 기울기2=2.2858, 절편=77.8560
# epochs=3600, 기울기1=1.5001, 기울기2=2.2858, 절편=77.8563
# epochs=3700, 기울기1=1.5001, 기울기2=2.2857, 절편=77.8566
# epochs=3800, 기울기1=1.5001, 기울기2=2.2857, 절편=77.8567
# epochs=3900, 기울기1=1.5000, 기울기2=2.2857, 절편=77.8568
# epochs=4000, 기울기1=1.5000, 기울기2=2.2857, 절편=77.8569
# epochs=4100, 기울기1=1.5000, 기울기2=2.2857, 절편=77.8570
# epochs=4200, 기울기1=1.5000, 기울기2=2.2857, 절편=77.8570
# epochs=4300, 기울기1=1.5000, 기울기2=2.2857, 절편=77.8571
# epochs=4400, 기울기1=1.5000, 기울기2=2.2857, 절편=77.8571
# epochs=4500, 기울기1=1.5000, 기울기2=2.2857, 절편=77.8571
# epochs=4600, 기울기1=1.5000, 기울기2=2.2857, 절편=77.8571
# epochs=4700, 기울기1=1.5000, 기울기2=2.2857, 절편=77.8571
# epochs=4800, 기울기1=1.5000, 기울기2=2.2857, 절편=77.8571
# epochs=4900, 기울기1=1.5000, 기울기2=2.2857, 절편=77.8571
# epochs=5000, 기울기1=1.5000, 기울기2=2.2857, 절편=77.8571

# %%
# y=1.5*x+2.2857*x2+77.8571
# 결과를 r을 통해 검증할 수도 있다

#다중 선형 회귀

# x1<-c(2,4,6,8)

# x2<-c(0,4,2,3)

# y<-c(81,93,91,97)

# linear_model2 <- lm(y ~ x1+x2)

# linear_model2

#+는 x1과 x2 독립적으로 고려해서 y에 미치는 영향 분석
#*는 x1과 x2 이 둘의 교호작용 항인 x1:x2 를 모두 포함

# linear_model2 <- lm(y ~ x1+x2)

# linear_model2

#교호작용 포함한 모델

# linear_model3_1 <- lm(y ~ x1*x2)

# linear_model3_1


# linear_model3_2 <- lm(y ~ x1+x2+x1:x2)

# linear_model3_2

# %%
#텐서플로에서 실행하는 선형 회귀, 다중 선형 회귀 모델

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np
import matplotlib.pyplot as plt

#텐서플로의 케라스 API에서 필요한 함수들을 불러 옵니다.
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
x = np.array([2, 4, 6, 8])
y = np.array([81, 93, 91, 97])

# %%
model=Sequential()

# %%
# tf.keras.layers.Dense(
#     units, #node
#     activation=None,
#     use_bias=True,
#     kernel_initializer='glorot_uniform',
#     bias_initializer='zeros',
#     kernel_regularizer=None,
#     bias_regularizer=None,
#     activity_regularizer=None,
#     kernel_constraint=None,
#     bias_constraint=None,
#     lora_rank=None,
#     **kwargs
# )

# %%
model.add(Dense())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[218], line 1
# ----> 1 model.add(Dense())
#
# File c:\ProgramData\anaconda3\envs\mldltest1\lib\site-packages\keras\src\dtensor\utils.py:96, in allow_initializer_layout.<locals>._wrap_function(layer_instance, *args, **kwargs)
#      93         if layout:
#      94             layout_args[variable_name + "_layout"] = layout
# ---> 96 init_method(layer_instance, *args, **kwargs)
#      98 # Inject the layout parameter after the invocation of __init__()
#      99 for layout_param_name, layout in layout_args.items():
#
# TypeError: __init__() missing 1 required positional argument: 'units'
